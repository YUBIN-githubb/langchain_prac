# %% [markdown]
# <a href="https://colab.research.google.com/github/YUBIN-githubb/langchain_prac/blob/main/document_loader_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain pypdf unstructured pdf2image docx2txt pdfminer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Document Loaders

# %% [markdown]
# Document Loader는 다양한 형식의 문서를 불러오고 이를 Langchain에 결합하기 쉬운 텍스트 형태로 변환하는 기능을 합니다. 이를 통해 사용자는 txt. 형식의 문서 뿐만 아니라 pdf, word, ppt, xlsx, csv 등 거의 모든 형식의 문서를 기반으로 LLM을 구동할 수 있습니다.

# %% [markdown]
# URL Document Loader
#
# LangChain은 웹에 기록된 글도 텍스트 형식으로 가져와 LLM에 활용할 수 있습니다. 대표적인 URL Loader는 WebBaseLoader와 UnstructuredURLLoader가 있습니다.

# %%
# !pip install -U langchain-community
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 10.6 MB/s eta 0:00:00
# ...

# %%
#이 url로 들어갈때 모든 텍스트를 다 가져옴. 태그에 있는 텍스트까지도
from langchain.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://n.news.naver.com/mnews/article/092/0002307222?sid=105")

data = loader.load()
print(data[0].page_content)
# Out:
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.
# "AI, 5년 뒤 사람보다 더 똑똑해진다"
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 본문 바로가기
#
#
#
#
#
#
# NAVER
#
# 뉴스
#
#
# 연예
#
#
#
#
# 스포츠
#
#
#
#
# 날씨
#
#
#
#
# 프리미엄
#
#
#
#
#
#
#
#
#
#
# 검색
#
#
#
#
#
#
#
#
#
#
# 언론사별
#
#
# 정치
#
#
# 경제
#
#
# 사회
#
#
# 생활/문화
#
#
# IT/과학
#
#
# 세계
#
#
# 랭킹
#
#
# 신문보기
#
#
# 오피니언
#
#
# TV
#
#
# 팩트체크
#
#
# 알고리즘 안내
#
#
# 정정보도 모음
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 구독
#
# 지디넷코리아 언론사 구독되었습니다. 메인 뉴스판에서  주요뉴스를  볼 수 있습니다.
# 보러가기
#
#
# 지디넷코리아 언론사 구독 해지되었습니다.
#
#
#
#
# PICK
# 안내
#
#
# 언론사가 주요기사로선정한 기사입니다.
# 언론사별 바로가기
# 닫기
#
#
#
#
# "AI, 5년 뒤 사람보다 더 똑똑해진다"
#
#
#
#
# 입력2023.10.09. 오후 12:27
#
# 기사원문
#
#
#
#
#
# 김미정 기자
#
# TALK
#
#
#
#
#
#
#
#
#
# 김미정 기자
#
# TALK
# 구독
# 구독중
#
#
#
#
# 구독자
# 0
#
#
# 응원수
# 0
#
#
#
# 더보기
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 추천
#
#
#
#
# 쏠쏠정보
# 0
#
#
#
#
# 흥미진진
# 0
#
#
#
#
# 공감백배
# 0
#
#
#
#
# 분석탁월
# 0
#
#
#
#
# 후속강추
# 0
#
#
#
#
#
#
# ...

# %%
# !pip install pdfminer.six

# %%
# !pip install Pillow

# %%
# !pip install pillow_heif
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 45.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.4.0 which is incompatible.
# ...

# %%
# !pip install unstructured[inference]
# Out:
# ...
# WARNING: unstructured 0.15.0 does not provide the extra 'inference'
# ...

# %%
from langchain.document_loaders import UnstructuredURLLoader


urls = [
    "https://n.news.naver.com/mnews/article/092/0002307222?sid=105",
    "https://n.news.naver.com/mnews/article/052/0001944792?sid=105",
]

loader = UnstructuredURLLoader(urls=urls)

data = loader.load()
data
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-1491bbc1dcc7> in <cell line: 11>()
#       9 loader = UnstructuredURLLoader(urls=urls)
#      10
# ---> 11 data = loader.load()
#      12 data
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/document_loaders/url.py in load(self)
#     108     def load(self) -> List[Document]:
#     109         """Load file."""
# --> 110         from unstructured.partition.auto import partition
#     111         from unstructured.partition.html import partition_html
#     112
#
# /usr/local/lib/python3.10/dist-packages/unstructured/partition/auto.py in <module>
#      76 pdf_imports = ["pdf2image", "pdfminer", "PIL"]
#      77 if all(dependency_exists(dep) for dep in pdf_imports):
# ---> 78     from unstructured.partition.pdf import partition_pdf
#      79
# ...

# %% [markdown]
# PDF Document Loader

# %%
from langchain.document_loaders import PyPDFLoader

loader = PyPDFLoader("/content/drive/MyDrive/포트폴리오_문유빈.pdf")
pages = loader.load_and_split()

# %%
pages
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/포트폴리오_문유빈.pdf', 'page': 0}, page_content='문유빈  이력서\n1😀\n문유빈  이력서  \n💡“불확실한  미래  속에서  스스로  자신만의  것을  만\n들어  낼  줄  아는  개발자 ˮ\n#백엔드개발자  #열정러  #스타트업\nC o n t a c t\n📧  de vyubin@gmail.com\n📱 \xa0010\ue0885329\ue08857 44\nC h a n n e l\n🔗  \nht tps://github.com/YUBIN-githubb\nA b o u t  M e\n헬스케어정보공학을  공부  중에  데이터를  다루는  과정에서  컴퓨터공학의  매력 , 즉  데이\n터를  어떻게  활용하고  효과적으로  처리할  수  있는가에  대한  매력을  느꼈습니다 . 이러한  \n관심은  컴퓨터공학을  복수전공하겠다는  결심으로  이어졌고  이로써  더  넓은  기술적  관점\n을  가지게  되었습니다 . \n복수전공  시작  후  다양한  과목을  수강하면서  프로그래밍  언어의  사용방법 , 전체적인  컴\n퓨터의  구조와  동작방식에  대해서  알게  되었습니다 . 또한  실무웹개발자  과정을  통해  웹\n의  구조와  작동  방식을  깊이  있게  배우게  되었으며 , 웹페이지  예제를  유지 , 보수하면서  \n내가  원하는  기능이나  디자인을  구현하는  성취감을  느끼게  되었습니다 .\n개발자로서의  제  목표는  “ 불확실한  미래  속에서  스스로  자신만의  것을  만들어  낼  줄  아\n는  개발자 ˮ 가  되는  것입니다 . 기술이  끊임없이  변화하고 , 새로운  도전이  계속되는  환경\n에서 , 변화를  두려워하지  않고  오히려  그  속에서  기회를  발견하고자  합니다 . 불확실한  미'),
# ...

# %%
print(pages[1].page_content)
# Out:
# 문유빈  이력서
# 2래에도  흔들리지  않고  열정과  노력을  다해서  가치  있는  결과물을  완성해내는  개발자가
# 되고  싶습니다 .
# S k i l l s
# 󾠮  경험  해봤어요  󾠯   자주  사용해요  󾠰   숙련된  기술입니다
# F r ont -End : 󾠮  ja v ascr ipt, 󾠮  html, 󾠮  css
# Back -End : 󾠮  e xpr ess, 󾠮  Ja v a
# Dat ab ase : 󾠮  M ySQL
# P o r t f o l i o
# 커뮤니티  웹  페이지  개발
# 전북대  7 기  문유빈  r e
# ht tps://y outu.be/2E1I vOBL Qb w
# [전북대  웹개발 ] 인공지능  리터러시  및  파이썬  기본 ( 전북대 )- 수료증 - 문유빈 .pdf
# E d u c a t i o n
# 2021. 03 - 202 4 . 05 전북대학교  바이오메디컬공학부  헬스케어정보공학과 , 컴퓨터인공지
# 능학부  IT 정보공학과  재학중

# %% [markdown]
# Word Document Loader

# %%
# !pip install docx2txt

# %%
from langchain.document_loaders import Docx2txtLoader
loader = Docx2txtLoader("/content/drive/MyDrive/실습과제7_템플릿.docx")
data = loader.load()

# %%
data
# Out:
# [Document(metadata={'source': '/content/drive/MyDrive/실습과제7_템플릿.docx'}, page_content='과제#7 결과보고서\n\n이름\n\n학과\n\n학번\n\n문유빈\n\n바이오메디컬공학부\n\n202110835\n\n\n\n완성한 코드 (add_node와 traverse_nodes 함수를 각각 스크린샷)\n\n\n\n\n\n\n\n\n\n\n\n실행 결과')]

# %%
data[0].metadata
# Out:
# {'source': '/content/drive/MyDrive/실습과제7_템플릿.docx'}

# %% [markdown]
# CSV Document Loader

# %%
from langchain.document_loaders.csv_loader import CSVLoader

# %%
#없는 파일
loader = CSVLoader(file_path='/content/drive/MyDrive/basketball.csv', csv_args={
    'delimiter': ',',
    'quotechar': '"',
    'fieldnames': ['ID', 'Name', 'Position', 'Height', 'Weight', 'Sponsorship Earnings', 'Shoe Sponsor', 'Career Stage', 'Age']
})

data = loader.load()
